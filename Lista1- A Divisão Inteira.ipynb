# %%
v1= int (input())
v2= int (input())
r1= v1/v2
r2= v1%v2
print('%.0f' % r1)
print('%.0f' % r2)
# Out:
# 123454321
# 54321
# 2273
# 37009

# %%
v1= int (input())
v2= int (input())
r1= v1//v2 #usar / não seria o ideal, pois iria arredondar o último número errado
r2= v1%v2
print(int (r1))
print(int (r2))
# Out:
# 987654321
# 563
# 1754270
# 311
