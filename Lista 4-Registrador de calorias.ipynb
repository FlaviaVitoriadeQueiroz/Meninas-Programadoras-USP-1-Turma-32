# %%
calorias_recomendadas = int(input())
calorias_consumidas = 0

while calorias_consumidas < calorias_recomendadas:
    calorias = int(input())
    calorias_consumidas += calorias

print(f"total: {calorias_consumidas}")
