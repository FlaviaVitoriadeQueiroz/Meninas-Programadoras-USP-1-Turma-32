# %%
cont = int (input())
for item in range(cont):
  valor = input()
if valor != valor_especifico:
  print('OK')
else:
  print('ERRO')
# Out:
# 3
# 4
# 5
# 6
# ERRO

# %%
numeros_digitados = []
cont = int(input())
for i in range(cont):
    valor = input()
    numeros_digitados.append(valor)
if valor in numeros_digitados:
  print('ERRO')
else:
  print('OK')
# Out:
# 2
# 2
# 1
# ERRO

# %%
numeros_digitados = []
cont = int(input())
houve_repeticao = False

for i in range(cont):
    valor = input()
    if valor in numeros_digitados:
        houve_repeticao = True
    else:
        numeros_digitados.append(valor)

if houve_repeticao:
    print('ERRO')
else:
    print('OK')
# Out:
# 2
# 1
# 2
# OK
