# %%
vminimo = int (input())
cont = 0
while vminimo > cont:
  tentativa= int (input())
  cont = tentativa + cont
sobra = cont - vminimo
print('minimo', vminimo)
print('total', cont)
print('sobra', sobra)
# Out:
# 100
# 50
# 51
# minimo 100
# total 101
# sobra 1
