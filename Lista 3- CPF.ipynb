# %%
cpf = input()
saida = ""
for i in cpf:
  if i != "." and i != "-":
    saida= saida + i
print(saida)
# Out:
# 88899000
# 88899000

# %%
cpf = input()
saida = ""
for i in cpf:
 saida = ""
 if  i != "." and i != "-" and i != '1234567890':
  saida = ""
  saida = saida + 1
  print(saida)
 elif cpf != '.' and i != '.' and i != '-':
  print('SIZE ERROR')
 elif cpf != '.' and cpf != '-' and cpf != 'a' and cpf != 'b' and cpf != 'c' and cpf != 'd' and cpf != 'e'and cpf != 'f' and cpf !='g' and cpf != 'h' and cpf != 'ijklmnopqrstuvwxyz':
  print('ENCODING ERROR')

# %%
cpf = input()
saida= ''
if cpf == 'A' and cpf =='B':
  print('ENCODING ERROR')
elif cpf == '.':
  print('SIZE ERROR')
else:
  for i in cpf:
    saida= saida + i
  print(saida)
# Out:
# 123.456.78-90
# 123.456.78-90

# %%
cpf = input()
cpfSemPonto = ''
for i in cpf:
  if i != "." and i != "-":
    cpfSemPonto =  cpfSemPonto + i

if cpfSemPonto... :
   print(...)
elif:
   print(...)
else:
   print(cpfSemPonto)

# %%
cpf = input()
saida = ""
letras = 0
cont = 0

for i in cpf:
  if i != "." and i != "-":
    saida = saida + i
    cont = cont + 1

for i in saida:
  if not(i in "1234567890"):
    letras = letras + 1

if letras > 0:
  print('ENCODING ERROR')
if cont != 11:
  print('SIZE ERROR')
if letras == 0 and cont == 11:
  print(saida)
# Out:
# 123.456.789-XX
# ENCODING ERROR
# 123456789XX
