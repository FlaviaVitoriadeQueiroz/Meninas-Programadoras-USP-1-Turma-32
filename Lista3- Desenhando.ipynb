# %%
numero = input()
simbulo = '*'
for digito in numero:
  if '0' <= digito <= '9':
    print(simbulo * int(digito))
# Out:
# 90807060504030201
# *********
#
# ********
#
# *******
#
# ******
#
# *****
#
# ****
#
# ***
#
# **
#
# *
