# %%
idade1= int (input())
idade2= int (input())
idade3= int (input())
idade4= int (input())
maisvelha= idade1
if idade2> maisvelha:
maisvelha= idade2
if idade3> maisvelha:
maisvelha= idade3
if idade4> maisvelha:
= idade4
print(f'A mais velha tem {maisvelha} anos')

# %%
idade1= int (input())
idade2= int (input())
idade3= int (input())
idade4= int (input())
maisvelha= idade1
if idade2> maisvelha:
  maisvelha= idade2
if idade3> maisvelha:
  maisvelha= idade3
if idade4> maisvelha:
  maisvelha= idade4
print(f'A mais velha tem {maisvelha} anos')
# Out:
# 18
# 20
# 14
# 45
# A mais velha tem 45 anos
