# %%
nvotos = int (input())
for i in range(nvotos):
  votos = input()
if votos == 'F':
  print('a favor:')
elif votos == 'C':
  print('contra:')
else:
  print('outros:')
# Out:
# 3
# F
# F
# F
# a favor

# %%
nvotos = int (input())
contf = 0
contc = 0
conto = 0
for i in range(nvotos):
  votos = input()
  if votos == 'F' or votos == 'f':
    contf += 1
  elif votos == 'C' or votos == 'c':
    contc += 1
  else:
    conto +=1
print('a favor:', contf)
print('contra:',contc)
print('outros:',conto)
# Out:
# 3
# f
# f
#
# a favor: 2
#  contra: 0
#  outros: 1
