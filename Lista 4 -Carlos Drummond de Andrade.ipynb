# %%
contador = 0
entrada = input()

while entrada != "CDA 1942":
    if entrada != "":
        contador += 1
    entrada = input()

print(contador)
# Out:
# CDA 1942
# 0

# %%
palavra = ''
entrada = input()
while entrada != "CDA":
    if entrada != "":
     entrada = input()
     palavra = entrada + palavra
print(palavra, '1942')
# Out:
# kkkkk
# hshsddh
# CDA
# CDAhshsddh 1942

# %%
while True:
    entrada = input()
    if entrada == "CDA":
        print("CDA 1942")
        break
    print(entrada)
