# %%
tenho = int(input())
cont = 0
coisa = 0
while 0 < tenho:
  coisa = int(input())
  tenho = tenho - coisa
  cont = cont + 1
if tenho < 0:
  cont = cont - 1
  tenho =  tenho + coisa
print('Número de itens', cont)
print(f'Saldo: %.2f' %tenho )
# Out:
# 100
# 30
# 50
# 30
# Número de itens 2
# Saldo: 20.00
