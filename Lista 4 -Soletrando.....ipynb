# %%
palavra =  ''
certo =  input ()
entrada =  0
while  entrada !=  '.' :
  entrada=  entrada () if  entrada !=  '.' :     palavra = palavra + entrada if  palavra == certo : print ( 'True' ) else : print ( 'False' )
# Out:
# muito
# m
# u
# i
# n
# t
# o
# .
# False
