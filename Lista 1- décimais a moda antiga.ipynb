# %%
valor = float (input ())
print ('%.2f' % valor)
print ('%.4f' % valor)
print ('%.6f' % valor)
print ('%.8f' % valor)
print ('%.10f' % valor)
#o f serve para formatar, por exemplo, mostrar 10.15 em vez de 10.555555

# %%
valor = float (input ())
n = 0
for i in range(5):
  n = n + 2
  print (f'{valor:.{n}f}')
