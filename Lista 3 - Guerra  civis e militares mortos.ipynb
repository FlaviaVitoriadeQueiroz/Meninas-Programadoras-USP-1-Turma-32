# %%
n = int (input())
cont = 0
contm = 0
dados = 0
for i in range(n):
  dados = input()
  if dados == 'Civil':
    cont = cont + 1
  elif dados == 'Militar':
    contm = contm + 1
print('civis mortos', cont)
print('militares mortos', contm)
# Out:
# 5
# Militar
# Civil
# Civil
# Militar
# Militar
# civis mortos 2
# militares mortos 3
