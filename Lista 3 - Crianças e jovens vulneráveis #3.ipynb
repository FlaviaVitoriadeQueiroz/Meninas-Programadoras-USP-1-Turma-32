# %%
redes = int(input())
horas = 0
minutos = 0
totalmin = 0
for i in range(redes):
  horas = int(input())
  minutos = int(input())
  total= (horas * 60) + minutos
  totalmin = totalmin + total
print(totalmin)
# Out:
# 2
# 1
# 30
# 1
# 00
# 150
