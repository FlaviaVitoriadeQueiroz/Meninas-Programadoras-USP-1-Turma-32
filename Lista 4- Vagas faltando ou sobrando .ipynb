# %%
vagas = int(input())
inscritas = 0

while True:
    nome = input()
    if nome == ".":
        break
    inscritas += 1

faltando = inscritas - vagas
sobrando = vagas - inscritas

if faltando > 0:
    print(f"vagas faltando: {faltando}")
else:
    print(f"vagas sobrando: {sobrando}"
