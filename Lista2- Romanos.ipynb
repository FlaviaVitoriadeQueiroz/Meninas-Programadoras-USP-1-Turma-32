# %%
letra= input()
if letra=='I':
  print('1')
elif letra=='V':
  print('5')
elif letra=='X':
  print('10')
elif letra=='L':
  print('50')
elif letra=='C':
  print('100')
elif letra=='D':
  print('500')
elif letra=='M':
  print('1000')
# Out:
# M
# 1000
