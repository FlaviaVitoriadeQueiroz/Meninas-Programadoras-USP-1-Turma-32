# %%
del print
n = int(input())
proximo= n + 1
print(str(proximo))
# Out:
# 8
# 9

# %%
n = int(input())
anterior= n - 1
print(str(anterior))
# Out:
# 0
# -1

# %%
n = int(input())
dobro= n *2
print(str(dobro))
# Out:
# -1
# -2

# %%
n = int(input())
metade= n /2
print('%.1f' % metade)
#ou
# Out:
# 9
# 4.5

# %%
n= int (input())
resultado= n/2
print (f"{resultado:.1f}")
