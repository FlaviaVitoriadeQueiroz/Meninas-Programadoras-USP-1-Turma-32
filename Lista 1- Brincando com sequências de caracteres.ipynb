# %%
letra1= input()
letra2= input()
cs1= input()
cs2= input()
ni= int (input())
soma1= letra1+cs1
soma2= letra2+cs2
soma3= (soma1+soma2) * ni
print(soma1)
print(soma2)
print(soma3)
# Out:
# f
# ´
# a
# ~
# 3
# fa
# ´~
# fa´~fa´~fa´~
