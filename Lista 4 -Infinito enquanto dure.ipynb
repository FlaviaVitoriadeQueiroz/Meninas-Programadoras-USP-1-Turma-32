# %%
cont =  0
entrada =  0
condiparada =  input ()
while  entrada != condiparada :
  cont= cont +  1
  entrada =  input () if  entrada == condiparada :     cont = cont  -1 print ( cont )
# Out:
# brasil
# jndjsend7nmdfdf
# hdsfjsd
# hbfhds
# hbdfhdhf
# bdhfe
# brasil
# 5
