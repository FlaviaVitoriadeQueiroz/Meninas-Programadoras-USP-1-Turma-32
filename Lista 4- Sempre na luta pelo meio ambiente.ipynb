# %%
pior =  input()
pior =  float ( pior )
cont =  0
cont1 = 0
while dados != -1:
  dados =  float ( input ())
  cont1 = cont1 + 1
  if  dados < pior :
    cont +=  1
    cont
print(cont1, cont)
# Out:
# 10.1

# %%
pior = float(input())
cont = 0
cont1 = 0
dados = 0
while dados != -1.0:
    dados = float(input())
    if dados != -1.0:
      cont1 += 1
      if dados < pior:
        cont += 1
print(cont1, cont)
# Out:
# 10.1
# 11.2
# 12.7
# -1
# 2 0
