# %%
dados = input()
substituir = input()
if dados == substituir:
  feito = substituir == '*'
  print(feito)
# Out:
# flavia vitoria
# aiv

# %%
dados = input()
sub = input()
resultado = ""

for caractere in dados:
    if caractere in sub:
        resultado += "*"
    else:
        resultado += caractere

print(resultado)
# Out:
# flavia vitoria de queiroz 18092005
# aivqz890
# fl**** **tor** de *ue*ro* 1***2**5
