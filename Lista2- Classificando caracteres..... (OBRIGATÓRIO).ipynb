# %%
entrada= input()
if entrada in '1234567890':
  print('algarismo')
elif entrada in '@#$%&*()_-+=!':
  print('especial')
elif entrada in 'AEIOUaeiou':
  print('vogal')
else:
  print('outro')
# Out:
# u
# vogal

# %% [markdown]
# If numero in "1234567890" == true:
#   Print("é número)
