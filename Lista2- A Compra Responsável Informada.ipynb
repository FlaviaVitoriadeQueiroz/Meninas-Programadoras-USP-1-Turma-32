# %%
valor1= int(input())
valor2= int (input())
if valor1<=valor2:
  print('seu saldo é insuficiente para essa compra')
elif valor1>valor2:
  saldo= valor1-valor2
  print(f'se você comprar tudo o saldo será: {saldo}')
# Out:
# 100
# 100
# seu saldo é insuficiente para essa compra
