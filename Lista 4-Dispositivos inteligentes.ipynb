# %%
movimento = 0
parado = 1
while True:
    entrada = input()
    if entrada == 'f':
        break
    elif entrada == 'm':
        movimento += 1
    elif entrada == 'p':
        parado += 1
if movimento > parado:
    print('ativo')
else:
    print('sedentário')
