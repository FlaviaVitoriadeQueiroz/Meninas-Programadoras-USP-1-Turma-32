# %%
bateria = int(input())

while bateria > 5:
    sensor1 = input()
    sensor2 = input()

    if sensor1 == 'B' and sensor2 == 'P':
        bateria -= 5
        print(f"virar: {bateria}")
    elif sensor1 == 'B' and sensor2 == 'A':
        break
    elif sensor1 == 'L' and sensor2 == 'P':
        bateria -= 1
        print(f"avançar: {bateria}")

print(f"recarregar: {bateria}")
