# %%
coisa =  1
arma =  0
maiorArma = 0
while   coisa !=   0 :
  entrada =  int ( input ())
  if  entrada >  0 :
    arma = arma + entrada
    if arma > maiorArma:
      maiorArma = arma
  elif  entrada <  0 :
    arma = arma + entrada
  else:
    coisa =  0
print (maiorArma)
# Out:
# 10
# -5
# 10
# -5
# 0
# 15
