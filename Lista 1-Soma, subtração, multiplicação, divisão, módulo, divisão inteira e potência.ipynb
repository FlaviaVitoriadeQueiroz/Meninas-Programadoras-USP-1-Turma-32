# %%
v1=  int ( entrada ())
v2=  int ( entrada ())
soma= v1+v2
sub= v1-v2
multi= v1*v2
div= v1/v2
mod= v1%v2
divint= v1//v2
pot= v1**v2
print ( int ( soma ))
print ( int ( sub ))
print ( int ( multi ))
print ( '%.2f'  % div )
print ( int ( mod ))
print ( int ( divint ))
print ( int ( pot ))
# Out:
# 2
# 1
# 3
# 1
# 2
# 2.00
# 0
# 2
# 2
