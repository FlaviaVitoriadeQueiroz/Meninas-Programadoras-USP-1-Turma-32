# %%
numeros =  int ( input ())
para  item  no intervalo ( 1 , 12 ):
  soma = numeros* item print ( soma )

# %%
numeros = int (input())
print(f'Tabuada do {numeros}')
for item in range(1, 12):
  soma = numeros* item
  print(f'{numeros} x {item} = {soma}')

# %%
tabuada = int (input())
primeiro = int (input())
ultimo = int (input())
arrumar = 0
print(f'Tabuada do {tabuada} de {primeiro} até {ultimo}')
for item in range(primeiro, ultimo+1):
  coisa = arrumar + primeiro
  soma = tabuada * item
  print(f'{tabuada} x {item} = {soma}')
